# %%
'''
This notebook is created in order to complete Capstone project which is the final part of Applied Data Science Certification.
'''

import pandas as pd
import numpy as np

print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
